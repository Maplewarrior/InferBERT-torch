# %%
import pandas as pd
import numpy as np

# %%
causal_tree = pd.read_csv("causal_tree.csv").sort_values(by="p value", ascending=False)
# drop na
causal_tree = causal_tree.dropna()
root_csv = pd.read_csv("root.csv")

# %%
causal_tree[causal_tree["route"].str.contains("Acetaminophen")].sort_values(by=["level", "z score"], ascending=True)
# Out:
#     level                           route     Feature            value  \
# 35      1                   Acetaminophen  indication          PYREXIA
# 34      1                   Acetaminophen      gender           Female
# 33      1                   Acetaminophen  indication  SUICIDE ATTEMPT
# 32      1                   Acetaminophen     outcome  LifeThreatening
# 31      1                   Acetaminophen        dose               PO
# 30      1                   Acetaminophen         age            18-39
# 29      1                   Acetaminophen     outcome            Death
# 67      2            Acetaminophen->Death      gender           Female
# 76      2            Death->Acetaminophen      gender           Female
# 95      2  younger than 18->Acetaminophen      gender           Female
# 86      2            18-39->Acetaminophen     outcome  LifeThreatening
# 70      2            Acetaminophen->18-39     outcome  LifeThreatening
# ...

# %%
root_csv.head()
# Out:
#       Feature                       value     z score  \
# 0         psd               Acetaminophen  174.653714
# 1     outcome                       Death  124.139744
# 2  indication  HEPATIC NEOPLASM MALIGNANT   82.204430
# 3     outcome             LifeThreatening   47.606564
# 4         psd          Sorafenib Tosylate   43.519920
#
#    probability of do value  probability of not do value  \
# 0                 0.844474                     0.367316
# 1                 0.707120                     0.345157
# 2                 0.797888                     0.406458
# 3                 0.631903                     0.444983
# 4                 0.780313                     0.428811
#
#    probability difference  p value  support
# 0                0.477158      0.0     4990
# 1                0.361963      0.0    11311
# 2                0.391430      0.0      271
# 3                0.186919      0.0     5488
# 4                0.351502      0.0      360
